# %% [markdown]
# <a href="https://colab.research.google.com/github/rasmitajena-lab/PYTHON-/blob/main/PYTHON_WORKSHOP_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Day 1**

# %%
import keyword
print ("no of keyword", len(keyword.kwlist))
# Out:
# no of keyword 35

# %%
import keyword
print("standard keywords=", len(keyword.kwlist))
print("soft keywords=", keyword. softkwlist)
print("all keyword=", keyword.kwlist)
# Out:
# standard keywords= 35
# soft keywords= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="john"
z= 3.0
print(x)
print(y)
print(z)
# Out:
# 5
# john
# 3.0

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1="john"
y2='john'
print(y1)
print(y2)
# Out:
# john
# john

# %%
y1=2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1= int(2)
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)

print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
c=50
d=float(c)
print(type(d))
# Out:
# <class 'float'>

# %%
a=2
A="Rasmi"
print(a)
print(A)
# Out:
# 2
# Rasmi

# %%
myname="rasmita"
my_dep="physics"
_my_university="SRU"
myLoc= "Warangal"
MYLOC="Telengana"
mydep2="PHY"

print(myname)
print(my_dep)
print(_my_university)
print(myLoc)
print(MYLOC)
print(mydep2)
# Out:
# rasmita
# physics
# SRU
# Warangal
# Telengana
# PHY

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print("======")
print("Sample Calculator")
print("======")
print("Addition=", a+b)
print("mul=",a*b)
print("Divison=", a/b)
print("Substraction=",a-b)
print("rem=",a%b)
print("======")
# Out:
# enter value of a30
# enter value of b40
# ...
# Sample Calculator
# ...
# Addition= 70
# mul= 1200
# Divison= 0.75
# Substraction= -10
# rem= 30
# ...
